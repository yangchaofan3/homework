# %%
# 员工离职预测
import pandas as pd
import numpy as np

# 数据加载
train = pd.read_csv('./attrition/train.csv')
test = test1 = pd.read_csv('./attrition/test.csv')
#print(train['Attrition'].value_counts())

# 设置标记位
test['Attrition']=-1
test = test[train.columns]
data = pd.concat([train, test])
# 处理Attrition字段
data['Attrition']=data['Attrition'].map(lambda x:1 if x=='Yes' else -1 if x==-1 else 0)

# 分类特征
cate = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
# 使用factorize将离散值对应为 index值
for feature in cate:
    data[feature] = pd.factorize(data[feature])[0]
#data.to_csv('temp.csv')
#print(data)

# 去掉没用的列 员工号码，标准工时（=80）

data = data.drop(['user_id', 'EmployeeNumber', 'StandardHours'], axis=1)
# 训练集测试集分离, 如果Attrition=-1 说明是测试集
train, test = data[data['Attrition']!=-1], data[data['Attrition']==-1]
#train = train.drop('Attrition', axis=1)
#print(train)
#print(len(train[train['Attrition']==1]),len(train[train['Attrition']==0]))

from sklearn.model_selection import train_test_split
# 划分训练集验证集
#X_train, X_test, y_train, y_test = train_test_split(train.drop('Attrition', axis=1), train['Attrition'], test_size=0.2, random_state=111)

from deepctr.models import DeepFM
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from deepctr.inputs import  SparseFeat, DenseFeat,get_feature_names

sparse_features = cate
# 除了分类特征以外，其余都是稠密类型
dense_features = list(set([i if i not in cate else '' for i in train.drop('Attrition', axis=1).columns]))
dense_features.remove('')
# 处理缺失值
train[sparse_features] = train[sparse_features].fillna('-1', )
train[dense_features] = train[dense_features].fillna(0, )
# 对离散特征进行标签编码
target = ['Attrition']
for feat in sparse_features:
    lbe = LabelEncoder()
    data[feat] = lbe.fit_transform(data[feat])
#print(data)

# 对数据进行0-1规划反
mms = MinMaxScaler(feature_range=(0, 1))
train[dense_features] = mms.fit_transform(train[dense_features])
test[dense_features] = mms.fit_transform(test[dense_features])
# 处理定长离散特征
fixlen_feature_columns = [SparseFeat(feat, data[feat].nunique())
                          for feat in sparse_features] + [DenseFeat(feat, 1,)
                          for feat in dense_features]

dnn_feature_columns = fixlen_feature_columns
linear_feature_columns = fixlen_feature_columns
print(fixlen_feature_columns)

# 得到所有特证名
feature_names = get_feature_names(linear_feature_columns + dnn_feature_columns)

train_model_input = {name:train[name] for name in feature_names}
model = DeepFM(linear_feature_columns, dnn_feature_columns, task='binary')
model.compile("adam", "binary_crossentropy", metrics=['binary_crossentropy'], )

history = model.fit(train_model_input, train[target].values,
                    batch_size=256, epochs=50, verbose=2, validation_split=0.2, )

# 对测试集进行预测
test_model_input = {name:test[name] for name in feature_names}
#print(test_model_input)
predict = model.predict(test_model_input, batch_size=256)
## 转化为二分类输出
test1['Attrition'] = predict
test1['Attrition']=test1['Attrition'].map(lambda x:1 if x>=0.5 else 0)
# 使用user_id作为索引
test1.set_index(["user_id"], inplace=True)
test1[['Attrition']].to_csv('submit_deepfm.csv')
# Out:
# C:\Users\Ricardo\Anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\Ricardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Ricardo\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Users\Ricardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Ricardo\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# [SparseFeat(name='BusinessTravel', vocabulary_size=3, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='BusinessTravel', group_name='default_group'), SparseFeat(name='Department', vocabulary_size=3, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='Department', group_name='default_group'), SparseFeat(name='EducationField', vocabulary_size=6, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='EducationField', group_name='default_group'), SparseFeat(name='Gender', vocabulary_size=2, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='Gender', group_name='default_group'), SparseFeat(name='JobRole', vocabulary_size=9, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='JobRole', group_name='default_group'), SparseFeat(name='MaritalStatus', vocabulary_size=3, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='MaritalStatus', group_name='default_group'), SparseFeat(name='Over18', vocabulary_size=1, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='Over18', group_name='default_group'), SparseFeat(name='OverTime', vocabulary_size=2, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='OverTime', group_name='default_group'), DenseFeat(name='EmployeeCount', dimension=1, dtype='float32'), DenseFeat(name='YearsAtCompany', dimension=1, dtype='float32'), DenseFeat(name='DailyRate', dimension=1, dtype='float32'), DenseFeat(name='Age', dimension=1, dtype='float32'), DenseFeat(name='MonthlyRate', dimension=1, dtype='float32'), DenseFeat(name='RelationshipSatisfaction', dimension=1, dtype='float32'), DenseFeat(name='NumCompaniesWorked', dimension=1, dtype='float32'), DenseFeat(name='JobSatisfaction', dimension=1, dtype='float32'), DenseFeat(name='StockOptionLevel', dimension=1, dtype='float32'), DenseFeat(name='Education', dimension=1, dtype='float32'), DenseFeat(name='YearsWithCurrManager', dimension=1, dtype='float32'), DenseFeat(name='TrainingTimesLastYear', dimension=1, dtype='float32'), DenseFeat(name='JobLevel', dimension=1, dtype='float32'), DenseFeat(name='MonthlyIncome', dimension=1, dtype='float32'), DenseFeat(name='EnvironmentSatisfaction', dimension=1, dtype='float32'), DenseFeat(name='PerformanceRating', dimension=1, dtype='float32'), DenseFeat(name='WorkLifeBalance', dimension=1, dtype='float32'), DenseFeat(name='HourlyRate', dimension=1, dtype='float32'), DenseFeat(name='DistanceFromHome', dimension=1, dtype='float32'), DenseFeat(name='YearsInCurrentRole', dimension=1, dtype='float32'), DenseFeat(name='YearsSinceLastPromotion', dimension=1, dtype='float32'), DenseFeat(name='PercentSalaryHike', dimension=1, dtype='float32'), DenseFeat(name='TotalWorkingYears', dimension=1, dtype='float32'), DenseFeat(name='JobInvolvement', dimension=1, dtype='float32')]
# Train on 940 samples, validate on 236 samples
# Epoch 1/50
#  - 2s - loss: 0.6511 - binary_crossentropy: 0.6511 - val_loss: 0.5659 - val_binary_crossentropy: 0.5659
# Epoch 2/50
#  - 0s - loss: 0.5079 - binary_crossentropy: 0.5078 - val_loss: 0.4854 - val_binary_crossentropy: 0.4854
# Epoch 3/50
#  - 0s - loss: 0.4330 - binary_crossentropy: 0.4330 - val_loss: 0.4784 - val_binary_crossentropy: 0.4784
# Epoch 4/50
#  - 0s - loss: 0.4162 - binary_crossentropy: 0.4162 - val_loss: 0.5051 - val_binary_crossentropy: 0.5051
# Epoch 5/50
#  - 0s - loss: 0.4239 - binary_crossentropy: 0.4239 - val_loss: 0.5073 - val_binary_crossentropy: 0.5073
# Epoch 6/50
#  - 0s - loss: 0.4185 - binary_crossentropy: 0.4185 - val_loss: 0.4892 - val_binary_crossentropy: 0.4892
# Epoch 7/50
#  - 0s - loss: 0.4056 - binary_crossentropy: 0.4056 - val_loss: 0.4714 - val_binary_crossentropy: 0.4714
# Epoch 8/50
#  - 0s - loss: 0.3979 - binary_crossentropy: 0.3979 - val_loss: 0.4625 - val_binary_crossentropy: 0.4625
# Epoch 9/50
#  - 0s - loss: 0.3956 - binary_crossentropy: 0.3956 - val_loss: 0.4583 - val_binary_crossentropy: 0.4583
# Epoch 10/50
#  - 0s - loss: 0.3922 - binary_crossentropy: 0.3922 - val_loss: 0.4548 - val_binary_crossentropy: 0.4548
# Epoch 11/50
#  - 0s - loss: 0.3846 - binary_crossentropy: 0.3846 - val_loss: 0.4528 - val_binary_crossentropy: 0.4528
# Epoch 12/50
#  - 0s - loss: 0.3779 - binary_crossentropy: 0.3779 - val_loss: 0.4515 - val_binary_crossentropy: 0.4515
# Epoch 13/50
#  - 0s - loss: 0.3720 - binary_crossentropy: 0.3720 - val_loss: 0.4494 - val_binary_crossentropy: 0.4494
# Epoch 14/50
#  - 0s - loss: 0.3647 - binary_crossentropy: 0.3647 - val_loss: 0.4411 - val_binary_crossentropy: 0.4411
# Epoch 15/50
#  - 0s - loss: 0.3567 - binary_crossentropy: 0.3567 - val_loss: 0.4335 - val_binary_crossentropy: 0.4335
# Epoch 16/50
#  - 0s - loss: 0.3490 - binary_crossentropy: 0.3490 - val_loss: 0.4288 - val_binary_crossentropy: 0.4288
# Epoch 17/50
#  - 0s - loss: 0.3397 - binary_crossentropy: 0.3397 - val_loss: 0.4269 - val_binary_crossentropy: 0.4269
# Epoch 18/50
#  - 0s - loss: 0.3314 - binary_crossentropy: 0.3314 - val_loss: 0.4221 - val_binary_crossentropy: 0.4221
# Epoch 19/50
#  - 0s - loss: 0.3211 - binary_crossentropy: 0.3211 - val_loss: 0.4167 - val_binary_crossentropy: 0.4167
# Epoch 20/50
#  - 0s - loss: 0.3120 - binary_crossentropy: 0.3120 - val_loss: 0.4127 - val_binary_crossentropy: 0.4127
# Epoch 21/50
#  - 0s - loss: 0.3039 - binary_crossentropy: 0.3039 - val_loss: 0.4114 - val_binary_crossentropy: 0.4114
# Epoch 22/50
#  - 0s - loss: 0.2956 - binary_crossentropy: 0.2956 - val_loss: 0.4114 - val_binary_crossentropy: 0.4114
# Epoch 23/50
#  - 0s - loss: 0.2894 - binary_crossentropy: 0.2894 - val_loss: 0.4126 - val_binary_crossentropy: 0.4126
# Epoch 24/50
#  - 0s - loss: 0.2842 - binary_crossentropy: 0.2841 - val_loss: 0.4117 - val_binary_crossentropy: 0.4117
# Epoch 25/50
#  - 0s - loss: 0.2793 - binary_crossentropy: 0.2792 - val_loss: 0.4144 - val_binary_crossentropy: 0.4144
# Epoch 26/50
#  - 0s - loss: 0.2751 - binary_crossentropy: 0.2751 - val_loss: 0.4112 - val_binary_crossentropy: 0.4112
# Epoch 27/50
#  - 0s - loss: 0.2711 - binary_crossentropy: 0.2711 - val_loss: 0.4099 - val_binary_crossentropy: 0.4099
# Epoch 28/50
#  - 0s - loss: 0.2673 - binary_crossentropy: 0.2673 - val_loss: 0.4122 - val_binary_crossentropy: 0.4122
# Epoch 29/50
#  - 0s - loss: 0.2633 - binary_crossentropy: 0.2633 - val_loss: 0.4055 - val_binary_crossentropy: 0.4055
# Epoch 30/50
#  - 0s - loss: 0.2599 - binary_crossentropy: 0.2599 - val_loss: 0.4037 - val_binary_crossentropy: 0.4037
# Epoch 31/50
#  - 0s - loss: 0.2576 - binary_crossentropy: 0.2576 - val_loss: 0.4075 - val_binary_crossentropy: 0.4075
# Epoch 32/50
#  - 0s - loss: 0.2533 - binary_crossentropy: 0.2532 - val_loss: 0.3999 - val_binary_crossentropy: 0.3999
# Epoch 33/50
#  - 0s - loss: 0.2503 - binary_crossentropy: 0.2503 - val_loss: 0.4000 - val_binary_crossentropy: 0.4000
# Epoch 34/50
#  - 0s - loss: 0.2464 - binary_crossentropy: 0.2464 - val_loss: 0.4046 - val_binary_crossentropy: 0.4046
# Epoch 35/50
#  - 0s - loss: 0.2458 - binary_crossentropy: 0.2458 - val_loss: 0.4004 - val_binary_crossentropy: 0.4004
# Epoch 36/50
#  - 0s - loss: 0.2393 - binary_crossentropy: 0.2393 - val_loss: 0.4088 - val_binary_crossentropy: 0.4087
# Epoch 37/50
#  - 0s - loss: 0.2373 - binary_crossentropy: 0.2373 - val_loss: 0.4035 - val_binary_crossentropy: 0.4035
# Epoch 38/50
#  - 0s - loss: 0.2331 - binary_crossentropy: 0.2330 - val_loss: 0.4014 - val_binary_crossentropy: 0.4013
# Epoch 39/50
#  - 0s - loss: 0.2313 - binary_crossentropy: 0.2313 - val_loss: 0.4019 - val_binary_crossentropy: 0.4019
# Epoch 40/50
#  - 0s - loss: 0.2274 - binary_crossentropy: 0.2274 - val_loss: 0.4021 - val_binary_crossentropy: 0.4021
# Epoch 41/50
#  - 0s - loss: 0.2231 - binary_crossentropy: 0.2231 - val_loss: 0.4009 - val_binary_crossentropy: 0.4009
# Epoch 42/50
#  - 0s - loss: 0.2213 - binary_crossentropy: 0.2212 - val_loss: 0.4027 - val_binary_crossentropy: 0.4026
# Epoch 43/50
#  - 0s - loss: 0.2192 - binary_crossentropy: 0.2192 - val_loss: 0.4025 - val_binary_crossentropy: 0.4025
# Epoch 44/50
#  - 0s - loss: 0.2162 - binary_crossentropy: 0.2162 - val_loss: 0.4074 - val_binary_crossentropy: 0.4074
# Epoch 45/50
#  - 0s - loss: 0.2104 - binary_crossentropy: 0.2104 - val_loss: 0.4013 - val_binary_crossentropy: 0.4013
# Epoch 46/50
#  - 0s - loss: 0.2074 - binary_crossentropy: 0.2073 - val_loss: 0.4079 - val_binary_crossentropy: 0.4079
# Epoch 47/50
#  - 0s - loss: 0.2040 - binary_crossentropy: 0.2040 - val_loss: 0.4080 - val_binary_crossentropy: 0.4080
# Epoch 48/50
#  - 0s - loss: 0.2012 - binary_crossentropy: 0.2012 - val_loss: 0.4059 - val_binary_crossentropy: 0.4059
# Epoch 49/50
#  - 0s - loss: 0.1964 - binary_crossentropy: 0.1964 - val_loss: 0.4083 - val_binary_crossentropy: 0.4083
# Epoch 50/50
#  - 0s - loss: 0.1949 - binary_crossentropy: 0.1949 - val_loss: 0.4072 - val_binary_crossentropy: 0.4072
