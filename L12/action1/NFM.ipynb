# %%
# 员工离职预测
import pandas as pd
import numpy as np

# 数据加载
train = pd.read_csv('./attrition/train.csv')
test = test1 = pd.read_csv('./attrition/test.csv')
#print(train['Attrition'].value_counts())

# 设置标记位
test['Attrition']=-1
test = test[train.columns]
data = pd.concat([train, test])
# 处理Attrition字段
data['Attrition']=data['Attrition'].map(lambda x:1 if x=='Yes' else -1 if x==-1 else 0)

# 分类特征
cate = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole', 'MaritalStatus', 'Over18', 'OverTime']
# 使用factorize将离散值对应为 index值
for feature in cate:
    data[feature] = pd.factorize(data[feature])[0]
#data.to_csv('temp.csv')
#print(data)

# 去掉没用的列员工号码，标准工时（=80）

data = data.drop(['user_id', 'EmployeeNumber', 'StandardHours'], axis=1)
# 训练集测试集分离, 如果Attrition=-1 说明是测试集
train, test = data[data['Attrition']!=-1], data[data['Attrition']==-1]
#train = train.drop('Attrition', axis=1)
#print(train)
#print(len(train[train['Attrition']==1]),len(train[train['Attrition']==0]))

from sklearn.model_selection import train_test_split
# 划分训练集验证集
#X_train, X_test, y_train, y_test = train_test_split(train.drop('Attrition', axis=1), train['Attrition'], test_size=0.2, random_state=111)

from deepctr.models import DeepFM, NFM
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from deepctr.inputs import  SparseFeat, DenseFeat,get_feature_names

sparse_features = cate
# 除了分类特征以外，其余都是稠密类型
dense_features = list(set([i if i not in cate else '' for i in train.drop('Attrition', axis=1).columns]))
dense_features.remove('')
# 处理缺失值
train[sparse_features] = train[sparse_features].fillna('-1', )
train[dense_features] = train[dense_features].fillna(0, )
# 对离散特征进行标签编码
target = ['Attrition']
for feat in sparse_features:
    lbe = LabelEncoder()
    data[feat] = lbe.fit_transform(data[feat])
#print(data)

# 对数据进行0-1规划反
mms = MinMaxScaler(feature_range=(0, 1))
train[dense_features] = mms.fit_transform(train[dense_features])
test[dense_features] = mms.fit_transform(test[dense_features])
# 处理定长离散特征
fixlen_feature_columns = [SparseFeat(feat, data[feat].nunique())
                          for feat in sparse_features] + [DenseFeat(feat, 1,)
                          for feat in dense_features]

dnn_feature_columns = fixlen_feature_columns
linear_feature_columns = fixlen_feature_columns
print(fixlen_feature_columns)

# 得到所有特证名
feature_names = get_feature_names(linear_feature_columns + dnn_feature_columns)

train_model_input = {name:train[name] for name in feature_names}
model = NFM(linear_feature_columns, dnn_feature_columns, task='binary')
model.compile("adam", "binary_crossentropy", metrics=['binary_crossentropy'], )

history = model.fit(train_model_input, train[target].values,
                    batch_size=256, epochs=50, verbose=2, validation_split=0.2, )

# 对测试集进行预测
test_model_input = {name:test[name] for name in feature_names}
#print(test_model_input)
predict = model.predict(test_model_input, batch_size=256)
## 转化为二分类输出
test1['Attrition'] = predict
test1['Attrition']=test1['Attrition'].map(lambda x:1 if x>=0.5 else 0)
# 使用user_id作为索引
test1.set_index(["user_id"], inplace=True)
test1[['Attrition']].to_csv('submit_nfm.csv')
# Out:
# C:\Users\Ricardo\Anaconda3\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# C:\Users\Ricardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Ricardo\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# C:\Users\Ricardo\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Ricardo\Anaconda3\lib\site-packages\pandas\core\indexing.py:966: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item] = s
# [SparseFeat(name='BusinessTravel', vocabulary_size=3, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='BusinessTravel', group_name='default_group'), SparseFeat(name='Department', vocabulary_size=3, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='Department', group_name='default_group'), SparseFeat(name='EducationField', vocabulary_size=6, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='EducationField', group_name='default_group'), SparseFeat(name='Gender', vocabulary_size=2, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='Gender', group_name='default_group'), SparseFeat(name='JobRole', vocabulary_size=9, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='JobRole', group_name='default_group'), SparseFeat(name='MaritalStatus', vocabulary_size=3, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='MaritalStatus', group_name='default_group'), SparseFeat(name='Over18', vocabulary_size=1, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='Over18', group_name='default_group'), SparseFeat(name='OverTime', vocabulary_size=2, embedding_dim=4, use_hash=False, dtype='int32', embedding_name='OverTime', group_name='default_group'), DenseFeat(name='PerformanceRating', dimension=1, dtype='float32'), DenseFeat(name='WorkLifeBalance', dimension=1, dtype='float32'), DenseFeat(name='RelationshipSatisfaction', dimension=1, dtype='float32'), DenseFeat(name='HourlyRate', dimension=1, dtype='float32'), DenseFeat(name='EnvironmentSatisfaction', dimension=1, dtype='float32'), DenseFeat(name='DailyRate', dimension=1, dtype='float32'), DenseFeat(name='YearsSinceLastPromotion', dimension=1, dtype='float32'), DenseFeat(name='TotalWorkingYears', dimension=1, dtype='float32'), DenseFeat(name='DistanceFromHome', dimension=1, dtype='float32'), DenseFeat(name='Age', dimension=1, dtype='float32'), DenseFeat(name='YearsInCurrentRole', dimension=1, dtype='float32'), DenseFeat(name='NumCompaniesWorked', dimension=1, dtype='float32'), DenseFeat(name='YearsWithCurrManager', dimension=1, dtype='float32'), DenseFeat(name='MonthlyRate', dimension=1, dtype='float32'), DenseFeat(name='Education', dimension=1, dtype='float32'), DenseFeat(name='EmployeeCount', dimension=1, dtype='float32'), DenseFeat(name='JobSatisfaction', dimension=1, dtype='float32'), DenseFeat(name='MonthlyIncome', dimension=1, dtype='float32'), DenseFeat(name='StockOptionLevel', dimension=1, dtype='float32'), DenseFeat(name='JobInvolvement', dimension=1, dtype='float32'), DenseFeat(name='PercentSalaryHike', dimension=1, dtype='float32'), DenseFeat(name='JobLevel', dimension=1, dtype='float32'), DenseFeat(name='YearsAtCompany', dimension=1, dtype='float32'), DenseFeat(name='TrainingTimesLastYear', dimension=1, dtype='float32')]
# Train on 940 samples, validate on 236 samples
# Epoch 1/50
#  - 2s - loss: 0.6690 - binary_crossentropy: 0.6690 - val_loss: 0.5920 - val_binary_crossentropy: 0.5920
# Epoch 2/50
#  - 0s - loss: 0.5416 - binary_crossentropy: 0.5416 - val_loss: 0.5050 - val_binary_crossentropy: 0.5050
# Epoch 3/50
#  - 0s - loss: 0.4519 - binary_crossentropy: 0.4519 - val_loss: 0.4611 - val_binary_crossentropy: 0.4611
# Epoch 4/50
#  - 0s - loss: 0.4055 - binary_crossentropy: 0.4054 - val_loss: 0.4655 - val_binary_crossentropy: 0.4655
# Epoch 5/50
#  - 0s - loss: 0.4021 - binary_crossentropy: 0.4021 - val_loss: 0.4882 - val_binary_crossentropy: 0.4882
# Epoch 6/50
#  - 0s - loss: 0.4085 - binary_crossentropy: 0.4085 - val_loss: 0.4857 - val_binary_crossentropy: 0.4857
# Epoch 7/50
#  - 0s - loss: 0.4010 - binary_crossentropy: 0.4010 - val_loss: 0.4683 - val_binary_crossentropy: 0.4683
# Epoch 8/50
#  - 0s - loss: 0.3912 - binary_crossentropy: 0.3912 - val_loss: 0.4553 - val_binary_crossentropy: 0.4553
# Epoch 9/50
#  - 0s - loss: 0.3869 - binary_crossentropy: 0.3868 - val_loss: 0.4505 - val_binary_crossentropy: 0.4505
# Epoch 10/50
#  - 0s - loss: 0.3851 - binary_crossentropy: 0.3851 - val_loss: 0.4488 - val_binary_crossentropy: 0.4488
# Epoch 11/50
#  - 0s - loss: 0.3816 - binary_crossentropy: 0.3816 - val_loss: 0.4476 - val_binary_crossentropy: 0.4476
# Epoch 12/50
#  - 0s - loss: 0.3763 - binary_crossentropy: 0.3763 - val_loss: 0.4497 - val_binary_crossentropy: 0.4497
# Epoch 13/50
#  - 0s - loss: 0.3716 - binary_crossentropy: 0.3716 - val_loss: 0.4512 - val_binary_crossentropy: 0.4511
# Epoch 14/50
#  - 0s - loss: 0.3685 - binary_crossentropy: 0.3684 - val_loss: 0.4497 - val_binary_crossentropy: 0.4497
# Epoch 15/50
#  - 0s - loss: 0.3621 - binary_crossentropy: 0.3621 - val_loss: 0.4436 - val_binary_crossentropy: 0.4436
# Epoch 16/50
#  - 0s - loss: 0.3585 - binary_crossentropy: 0.3585 - val_loss: 0.4402 - val_binary_crossentropy: 0.4402
# Epoch 17/50
#  - 0s - loss: 0.3520 - binary_crossentropy: 0.3520 - val_loss: 0.4388 - val_binary_crossentropy: 0.4388
# Epoch 18/50
#  - 0s - loss: 0.3456 - binary_crossentropy: 0.3455 - val_loss: 0.4392 - val_binary_crossentropy: 0.4392
# Epoch 19/50
#  - 0s - loss: 0.3386 - binary_crossentropy: 0.3386 - val_loss: 0.4356 - val_binary_crossentropy: 0.4356
# Epoch 20/50
#  - 0s - loss: 0.3304 - binary_crossentropy: 0.3303 - val_loss: 0.4288 - val_binary_crossentropy: 0.4288
# Epoch 21/50
#  - 0s - loss: 0.3223 - binary_crossentropy: 0.3223 - val_loss: 0.4246 - val_binary_crossentropy: 0.4246
# Epoch 22/50
#  - 0s - loss: 0.3115 - binary_crossentropy: 0.3115 - val_loss: 0.4230 - val_binary_crossentropy: 0.4230
# Epoch 23/50
#  - 0s - loss: 0.3034 - binary_crossentropy: 0.3034 - val_loss: 0.4180 - val_binary_crossentropy: 0.4180
# Epoch 24/50
#  - 0s - loss: 0.2933 - binary_crossentropy: 0.2932 - val_loss: 0.4156 - val_binary_crossentropy: 0.4156
# Epoch 25/50
#  - 0s - loss: 0.2868 - binary_crossentropy: 0.2868 - val_loss: 0.4120 - val_binary_crossentropy: 0.4119
# Epoch 26/50
#  - 0s - loss: 0.2792 - binary_crossentropy: 0.2792 - val_loss: 0.4144 - val_binary_crossentropy: 0.4144
# Epoch 27/50
#  - 0s - loss: 0.2743 - binary_crossentropy: 0.2743 - val_loss: 0.4107 - val_binary_crossentropy: 0.4107
# Epoch 28/50
#  - 0s - loss: 0.2700 - binary_crossentropy: 0.2700 - val_loss: 0.4060 - val_binary_crossentropy: 0.4059
# Epoch 29/50
#  - 0s - loss: 0.2640 - binary_crossentropy: 0.2640 - val_loss: 0.4115 - val_binary_crossentropy: 0.4114
# Epoch 30/50
#  - 0s - loss: 0.2637 - binary_crossentropy: 0.2637 - val_loss: 0.4114 - val_binary_crossentropy: 0.4114
# Epoch 31/50
#  - 0s - loss: 0.2609 - binary_crossentropy: 0.2608 - val_loss: 0.4031 - val_binary_crossentropy: 0.4031
# Epoch 32/50
#  - 0s - loss: 0.2547 - binary_crossentropy: 0.2547 - val_loss: 0.4129 - val_binary_crossentropy: 0.4128
# Epoch 33/50
#  - 0s - loss: 0.2513 - binary_crossentropy: 0.2512 - val_loss: 0.4065 - val_binary_crossentropy: 0.4065
# Epoch 34/50
#  - 0s - loss: 0.2483 - binary_crossentropy: 0.2483 - val_loss: 0.4019 - val_binary_crossentropy: 0.4019
# Epoch 35/50
#  - 0s - loss: 0.2448 - binary_crossentropy: 0.2448 - val_loss: 0.4108 - val_binary_crossentropy: 0.4108
# Epoch 36/50
#  - 0s - loss: 0.2411 - binary_crossentropy: 0.2411 - val_loss: 0.4045 - val_binary_crossentropy: 0.4045
# Epoch 37/50
#  - 0s - loss: 0.2402 - binary_crossentropy: 0.2402 - val_loss: 0.4001 - val_binary_crossentropy: 0.4001
# Epoch 38/50
#  - 0s - loss: 0.2351 - binary_crossentropy: 0.2350 - val_loss: 0.4110 - val_binary_crossentropy: 0.4110
# Epoch 39/50
#  - 0s - loss: 0.2338 - binary_crossentropy: 0.2338 - val_loss: 0.4051 - val_binary_crossentropy: 0.4050
# Epoch 40/50
#  - 0s - loss: 0.2276 - binary_crossentropy: 0.2276 - val_loss: 0.4031 - val_binary_crossentropy: 0.4031
# Epoch 41/50
#  - 0s - loss: 0.2253 - binary_crossentropy: 0.2252 - val_loss: 0.4073 - val_binary_crossentropy: 0.4073
# Epoch 42/50
#  - 0s - loss: 0.2210 - binary_crossentropy: 0.2210 - val_loss: 0.4075 - val_binary_crossentropy: 0.4074
# Epoch 43/50
#  - 0s - loss: 0.2209 - binary_crossentropy: 0.2209 - val_loss: 0.4082 - val_binary_crossentropy: 0.4082
# Epoch 44/50
#  - 0s - loss: 0.2170 - binary_crossentropy: 0.2170 - val_loss: 0.4160 - val_binary_crossentropy: 0.4160
# Epoch 45/50
#  - 0s - loss: 0.2110 - binary_crossentropy: 0.2110 - val_loss: 0.4084 - val_binary_crossentropy: 0.4084
# Epoch 46/50
#  - 0s - loss: 0.2099 - binary_crossentropy: 0.2099 - val_loss: 0.4107 - val_binary_crossentropy: 0.4107
# Epoch 47/50
#  - 0s - loss: 0.2052 - binary_crossentropy: 0.2052 - val_loss: 0.4166 - val_binary_crossentropy: 0.4166
# Epoch 48/50
#  - 0s - loss: 0.2015 - binary_crossentropy: 0.2014 - val_loss: 0.4109 - val_binary_crossentropy: 0.4108
# Epoch 49/50
#  - 0s - loss: 0.1987 - binary_crossentropy: 0.1987 - val_loss: 0.4137 - val_binary_crossentropy: 0.4137
# Epoch 50/50
#  - 0s - loss: 0.1956 - binary_crossentropy: 0.1956 - val_loss: 0.4215 - val_binary_crossentropy: 0.4215
