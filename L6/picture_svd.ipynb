# %%
import numpy as np
from scipy.linalg import svd
from PIL import Image
import matplotlib.pyplot as plt

# 取前k个特征，对图像进行还原
def get_image_feature(s, k):
	# 对于S，只保留前K个特征值
	s_temp = np.zeros(s.shape[0])
	s_temp[0:k] = s[0:k] 
	s = s_temp * np.identity(s.shape[0])    #方阵
	# 用新的s_temp，以及p,q重构A
	temp = np.dot(p,s)
	temp = np.dot(temp,q)
	plt.imshow(temp, cmap=plt.cm.gray, interpolation='nearest')
	plt.show()
	print(A-temp)
# 加载256色图片
image = Image.open('./selfie.jpg')
A = np.array(image)
# 显示原图像
plt.imshow(A, cmap=plt.cm.gray, interpolation='nearest')
plt.show()

# %%
#由于SVD无法结构彩色图的三维数组，需要先转成灰度图
image=image.convert('L')
A = np.array(image)
plt.imshow(A, cmap=plt.cm.gray, interpolation='nearest')
plt.show()

# %%
p,s,q = svd(A,full_matrices=False)
for k in [5,50,500]:
    print('保留前%d个特征时压缩图片输出：' % k)
    get_image_feature(s,k)
# Out:
# 保留前5个特征时压缩图片输出：
# [[ -2.21092367  -2.24979329  -2.34209414 ...  -0.67387268  -0.74374801
#    -0.81478011]
#  [ -2.21092367  -2.24979329  -2.34209414 ...  -0.67387268  -0.74374801
#    -0.81478012]
#  [ -2.21092367  -2.24979329  -2.34209414 ...  -0.67387268  -0.74374801
#    -0.81478012]
#  ...
#  [  0.42846933   1.39779054   4.32527242 ... -25.36487455   5.58040368
#    17.52467607]
#  [ 10.67715144  -0.35417318  -9.42876684 ... -25.08689145   9.8586467
#    26.80035971]
#  [  9.11893183  -2.91334331 -12.99032185 ... -26.60177877  -8.65908816
#     6.28117128]]
# 保留前50个特征时压缩图片输出：
# [[ -1.34034955  -1.43215398  -1.54770784 ...   0.46264362   0.26940939
#     0.13520658]
#  [ -1.34034955  -1.43215398  -1.54770784 ...   0.46264362   0.26940939
#     0.13520658]
#  [ -1.34034955  -1.43215398  -1.54770784 ...   0.46264362   0.26940939
#     0.13520658]
#  ...
#  [  0.51283838   1.83316731   4.80091587 ... -24.94255542   6.93520501
#    18.42374644]
#  [  6.01245523  -4.58559685 -13.61434608 ... -33.00875752   4.7174675
#    23.25499368]
#  [  7.50883011  -4.28516084 -14.27725902 ... -31.18714409 -10.33450763
#     7.30236643]]
# 保留前500个特征时压缩图片输出：
# [[ 0.16472636  0.11451067 -0.10331483 ... -0.02033516 -0.48692331
#   -0.04535654]
#  [ 0.16472636  0.11451067 -0.10331483 ... -0.02033516 -0.48692331
#   -0.04535654]
#  [ 0.16472636  0.11451067 -0.10331483 ... -0.02033516 -0.48692331
#   -0.04535654]
#  ...
#  [ 2.42807105  3.82326046  3.50166977 ... -2.2947272  -3.91256693
#   -5.29607876]
#  [-0.4196388  -0.35632622  0.58203384 ... -2.47758715 -1.22022246
#   -3.43625108]
#  [-3.61306424 -5.40957972 -2.20862997 ... -6.87600606 -7.32541288
#   -4.84389495]]
